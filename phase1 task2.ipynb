# %%
import pandas as pd
import numpy as np
import seaborn as sns

data=pd.read_csv('dataset - netflix1.csv')

# %%
data.head(10)
# Out:
#   show_id     type                             title             director  \
# 0      s1    Movie              Dick Johnson Is Dead      Kirsten Johnson
# 1      s3  TV Show                         Ganglands      Julien Leclercq
# 2      s6  TV Show                     Midnight Mass        Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl        Bruno Garotti
# 4      s8    Movie                           Sankofa         Haile Gerima
# 5      s9  TV Show     The Great British Baking Show      Andy Devonshire
# 6     s10    Movie                      The Starling       Theodore Melfi
# 7    s939    Movie   Motu Patlu in the Game of Zones          Suhas Kadav
# 8     s13    Movie                      Je Suis Karl  Christian Schwochow
# 9    s940    Movie          Motu Patlu in Wonderland          Suhas Kadav
#
#           country date_added  release_year rating   duration  \
# 0   United States  9/25/2021          2020  PG-13     90 min
# ...

# %%
data.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %%
data.drop_duplicates(inplace=True)

# %%
data.columns
print('missing values of each column: \n',len(data)-data.count())
# Out:
# missing values of each column:
#  show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
data.duplicated().value_counts()
# Out:
# False    8790
# Name: count, dtype: int64

# %%
data['release_year'].hist()
# Out:
# <Axes: >

# %%
data
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
a=data['release_year'].quantile(0.25)
b=data['release_year'].quantile(0.75)
c=b-a
ww=1
outliers=data[(data['release_year']<a-ww*c) | (data['release_year']>b+ww*c)]
outliers
new_data=data[(data['release_year']<a-ww*c) | (data['release_year']>b+ww*c)]
data.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
outliers
# Out:
#      show_id     type                                title          director  \
# 4         s8    Movie                              Sankofa      Haile Gerima
# 29       s25    Movie                                Jeans        S. Shankar
# 51       s27    Movie                       Minsara Kanavu       Rajiv Menon
# 53       s23    Movie                      Avvai Shanmughi    K.S. Ravikumar
# 60       s42    Movie                                 Jaws  Steven Spielberg
# ...      ...      ...                                  ...               ...
# 8743   s8524  TV Show    The Super Mario Bros. Super Show!         Not Given
# 8746   s8542  TV Show  The Twilight Zone (Original Series)         Not Given
# 8749   s8558  TV Show                        The West Wing         Not Given
# 8761   s8645  TV Show                           Twin Peaks         Not Given
# 8765   s8670  TV Show                        V.R. Troopers         Not Given
#
# ...

# %%
new_data.to_csv("cleaned_dataset.csv", index=False)
